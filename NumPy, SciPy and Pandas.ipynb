# %% [markdown]
# # NumPy, SciPy and Pandas

# %% [markdown]
# So let's get started

# %%
# some imports and config

import matplotlib.pyplot as plt

import mpld3
mpld3.enable_notebook()

import numpy as np
import pandas as pd 

from __future__ import print_function
import statsmodels.api as sm
from statsmodels.sandbox.regression.predstd import wls_prediction_std
np.random.seed(9876789)

from scipy import stats 

import fredapi 
fred = fredapi.Fred(api_key='266ecfe55e7ad829f235934dc60c4667')

# %% [markdown]
# Now let's get some data from st louis fed.

# %%
mv = fred.get_series('DGS10').resample('Q', how='mean')
gdp = fred.get_series('FEDFUNDS').resample('Q', how='mean')

# %%
combined = pd.concat([mv, gdp], axis=1) 
combined.columns = ["DGS10", "FEDFUNDS"]

combined.plot()

# %%
dfd = combined.diff().dropna()
dfd.plot()

# %%
y = dfd["DGS10"].values
x = dfd["FEDFUNDS"].values
result = sm.OLS( x, y ).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.284
# Model:                            OLS   Adj. R-squared:                  0.280
# Method:                 Least Squares   F-statistic:                     83.19
# Date:                Tue, 20 Jan 2015   Prob (F-statistic):           6.18e-17
# Time:                        15:51:06   Log-Likelihood:                -250.08
# No. Observations:                 211   AIC:                             502.2
# Df Residuals:                     210   BIC:                             505.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1             1.0272      0.113      9.121      0.000         0.805     1.249
# ==============================================================================
# Omnibus:                       44.509   Durbin-Watson:                   1.742
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              542.267
# Skew:                          -0.230   Prob(JB):                    1.77e-118
# Kurtosis:                      10.840   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
